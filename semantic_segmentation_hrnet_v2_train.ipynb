# %% [markdown]
# <a href="https://colab.research.google.com/github/alimoorreza/segbuilder_sem_seg/blob/main/semantic_segmentation_hrnet_v2_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/07/hsqbq3rx4xdg6syz29ctnpl00000gn/T/ipykernel_1160/2258033288.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive/')
#
# ModuleNotFoundError: No module named 'google'

# %%
! pip install gdown

# %%
! pip install imagecodecs
! pip install pickle5
! pip install timm
! pip install tensorboardX
! pip install yacs
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.6/39.6 MB 25.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255318 sha256=b88e28a740542896ff74a9b15a25ed59490902045e704c8714df83e51f0826cb
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...

# %%
![[ -d ./segbuilder_sem_seg ]] && rm -rf ./segbuilder_sem_seg
# !git clone https://github.com/alimoorreza/segbuilder_sem_seg
# Out:
# Cloning into 'segbuilder_sem_seg'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 172 (delta 10), reused 0 (delta 0), pack-reused 116
# Receiving objects: 100% (172/172), 157.15 KiB | 1.06 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# !mkdir -p segbuilder_sem_seg/log
# !mkdir -p segbuilder_sem_seg/output
# !mkdir -p segbuilder_sem_seg/init_model
# !mkdir -p segbuilder_sem_seg/dataset

# %% [markdown]
# Download the dataset

# %%
# !gdown https://drive.google.com/uc?id=1X12Ths6eeRM428vkasZQDuLS9sEMTldx
unzip /content/uw_sem_seg_dataset.zip -d segbuilder_sem_seg/dataset
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1X12Ths6eeRM428vkasZQDuLS9sEMTldx
# From (redirected): https://drive.google.com/uc?id=1X12Ths6eeRM428vkasZQDuLS9sEMTldx&confirm=t&uuid=ba61b062-0b79-4f94-aca6-30c5a5fa3e45
# To: /content/uw_sem_seg_dataset.zip
# 100% 571M/571M [00:02<00:00, 224MB/s]
# Archive:  /content/uw_sem_seg_dataset.zip
#    creating: segbuilder_sem_seg/dataset/uw_sem_seg_dataset/
#   inflating: segbuilder_sem_seg/dataset/__MACOSX/._uw_sem_seg_dataset
#    creating: segbuilder_sem_seg/dataset/uw_sem_seg_dataset/train/
#   inflating: segbuilder_sem_seg/dataset/__MACOSX/uw_sem_seg_dataset/._train
#   inflating: segbuilder_sem_seg/dataset/uw_sem_seg_dataset/._train
#    creating: segbuilder_sem_seg/dataset/uw_sem_seg_dataset/validation/
#   inflating: segbuilder_sem_seg/dataset/__MACOSX/uw_sem_seg_dataset/._validation
#   inflating: segbuilder_sem_seg/dataset/uw_sem_seg_dataset/._validation
# ...

# %% [markdown]
# Download the pretrained weights for hrnet-v2

# %%
# !gdown https://drive.google.com/uc?id=1CHOKZcn6TnThoajYmfwjJ9g7Q4SRW4k4
# !mv hrnetv2_w48_imagenet_pretrained.pth segbuilder_sem_seg/init_model/
#!mv hrnetv2_w48_imagenet_pretrained.pth "/content/drive/MyDrive/Colab Notebooks/research/semantic_segmentation/"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1CHOKZcn6TnThoajYmfwjJ9g7Q4SRW4k4
# From (redirected): https://drive.google.com/uc?id=1CHOKZcn6TnThoajYmfwjJ9g7Q4SRW4k4&confirm=t&uuid=ffe7fd45-ed54-4d09-8ba4-4322bb85d666
# To: /content/hrnetv2_w48_imagenet_pretrained.pth
# 100% 311M/311M [00:01<00:00, 161MB/s]

# %%
! find ./segbuilder_sem_seg -name "._*" -delete

# %%
# !python3 ./segbuilder_sem_seg/tools/train_hrnet_v2_final.py \
    --cfg ./segbuilder_sem_seg/experiments/hrnet/uws_training_hrnet_v2.yaml
# Out:
# Seeding with 304
# => creating ../output
# => creating ../output/UWS3/uws_training_hrnet_v2
# => creating ../log/UWS3/seg_hrnet/uws_training_hrnet_v2_2024-04-17-16-41
# Namespace(cfg='./segbuilder_sem_seg/experiments/hrnet/uws_training_hrnet_v2.yaml', seed=304, opts=[])
# AUTO_RESUME: False
# CUDNN:
#   BENCHMARK: True
#   DETERMINISTIC: False
#   ENABLED: True
# DATASET:
#   DATASET: UWS3
#   EXTRA_TRAIN_SET:
#   NUM_CLASSES: 29
#   ROOT: ../datasets/uw_sem_seg_dataset/
#   TEST_SET: validation
#   TRAIN_SET: train
# DEBUG:
#   DEBUG: False
#   SAVE_BATCH_IMAGES_GT: False
#   SAVE_BATCH_IMAGES_PRED: False
#   SAVE_HEATMAPS_GT: False
#   SAVE_HEATMAPS_PRED: False
# GPUS: (0, 1)
# LOG_DIR: ../log
# LOSS:
#   BALANCE_WEIGHTS: [1]
#   CLASS_BALANCE: False
#   OHEMKEEP: 131072
#   OHEMTHRES: 0.9
#   USE_OHEM: True
# MODEL:
#   ALIGN_CORNERS: True
#   EXTRA:
#     FINAL_CONV_KERNEL: 1
#     STAGE1:
#       BLOCK: BOTTLENECK
#       FUSE_METHOD: SUM
#       NUM_BLOCKS: [4]
# ...
