# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
Seedpath = '/content/drive/MyDrive/sameer/Final_data 02_2024/Label Studio vs SegBuilder/sameer/new_dataset_raw'
Targetpath = "/content/drive/MyDrive/sameer/Final_data 02_2024/Label Studio vs SegBuilder/sameer/Sean_output"

# %%
from google.colab import files
import os
import splitfolders

path = '/content/drive/MyDrive/sameer/Final_data 02_2024/Label Studio vs SegBuilder/sameer/new_dataset_raw'



for entry in os.listdir(path):
    full_path = os.path.join(path, entry)
    if os.path.isdir(full_path):
        print(full_path)
        splitfolders.ratio(full_path, Targetpath, seed=1337, ratio=(.8, .2))


# for root, dirs, files in os.walk(path):
#     for name in dirs:
#       print(os.path.join(root, name))
#         # splitfolders.ratio(os.path.join(root, name), Targetpath, seed=1337, ratio=(.8, .2))
# Out:
# /content/drive/MyDrive/sameer/Final_data 02_2024/Label Studio vs SegBuilder/sameer/new_dataset_raw/sea anemone
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 5 files [00:00, 44.06 files/s]
# Copying files: 10 files [00:00, 45.77 files/s]
# Copying files: 15 files [00:00, 40.05 files/s]
# Copying files: 20 files [00:00, 42.11 files/s]
# Copying files: 25 files [00:00, 36.48 files/s]
# Copying files: 31 files [00:00, 41.19 files/s]
# Copying files: 36 files [00:00, 40.98 files/s]
# Copying files: 41 files [00:01, 38.85 files/s]
# Copying files: 45 files [00:01, 37.96 files/s]
# Copying files: 49 files [00:01, 36.53 files/s]
# Copying files: 54 files [00:01, 38.07 files/s]
# /content/drive/MyDrive/sameer/Final_data 02_2024/Label Studio vs SegBuilder/sameer/new_dataset_raw/goldfish
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 4 files [00:00, 37.50 files/s]
# Copying files: 8 files [00:00, 36.58 files/s]
# Copying files: 13 files [00:00, 41.28 files/s]
# ...

# %%
# Out:
# Copying files: 0 files [00:00, ? files/s]
